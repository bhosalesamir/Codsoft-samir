# %% [markdown]
# <a href="https://colab.research.google.com/github/bhosalesamir/Codsoft-samir/blob/main/moview_review(dl2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import tensorflow as tf
 from tensorflow.keras import layers, models
 from tensorflow.keras.datasets import imdb
 from tensorflow.keras.preprocessing.sequence import pad_sequences
 import numpy as np

# %%
 num_words = 10000
 (X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=num_words)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
 maxlen = 500
 X_train = pad_sequences(X_train, maxlen=maxlen)
 X_test = pad_sequences(X_test, maxlen=maxlen)

# %%
 model = models.Sequential([
    layers.Embedding(input_dim=num_words, output_dim=32, input_length=maxlen),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(1, activation='sigmoid')
 ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
 model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
 model.fit(X_train, y_train, epochs=5, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - accuracy: 0.6343 - loss: 0.5960 - val_accuracy: 0.8726 - val_loss: 0.3059
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 13s 81ms/step - accuracy: 0.9415 - loss: 0.1604 - val_accuracy: 0.8670 - val_loss: 0.3337
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 13s 80ms/step - accuracy: 0.9931 - loss: 0.0389 - val_accuracy: 0.8602 - val_loss: 0.3907
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.9995 - loss: 0.0074 - val_accuracy: 0.8620 - val_loss: 0.4352
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8612 - val_loss: 0.4715

# %%
 test_loss, test_acc = model.evaluate(X_test, y_test)
 print(f"\nTest Accuracy: {test_acc:.4f}\n")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8576 - loss: 0.4733
#
# Test Accuracy: 0.8592

# %%
 word_index = imdb.get_word_index()
 reverse_word_index = {value + 3: key for key, value in word_index.items()}
 reverse_word_index[0] = '<PAD>'
 reverse_word_index[1] = '<START>'
 reverse_word_index[2] = '<UNK>'
 reverse_word_index[3] = '<UNUSED>'
# Out:
# ...
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
 def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i, '?') for i in encoded_review])

# %%
 num_samples = 5
 predictions = model.predict(X_test[:num_samples])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step

# %%
 for i in range(num_samples):
    print(f"\n--- Review {i+1} ---")
    print(decode_review(X_test[i]))
    print(f"Actual Label: {'Positive' if y_test[i] == 1 else 'Negative'}")
    print(f"Predicted Label: {'Positive' if predictions[i] >= 0.5 else 'Negative'}(Confidence: {predictions[i][0]:.2f})")
# Out:
# --- Review 1 ---
# ...
